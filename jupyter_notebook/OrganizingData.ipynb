# %%
#Importei os módulos necessarios
import os
import swimclub

#Listei os arquivos do diretorio swimdata/ que é a constante FOLDER
swim_files = os.listdir(swimclub.FOLDER)

#Removo o arquivo indesejado da lista
swim_files.remove('.DS_Store')

#Verifico se agora está realmente somente os 60 arquivos dos nadadores
print(len(swim_files))
# Out:
# 60

# %%
#Crio uma lista vazia chamada "nadadores"
swimmers = []

#Crio um loop for para processar os arquivos da lista e criar uma lista nova só com os nomes dos nadadores
for s in swim_files:
   #O zero acessa o primeiro indice da tupla (nome, categoria, distancia, estilo, tempos, media_formatada, convercoes)
   swimmers.append(swimclub.read_swim_data(s)[0])

print(swimmers)
# Out:
# ['Abi', 'Abi', 'Abi', 'Abi', 'Abi', 'Ali', 'Ali', 'Alison', 'Alison', 'Aurora', 'Bill', 'Bill', 'Blake', 'Blake', 'Blake', 'Calvin', 'Calvin', 'Calvin', 'Carl', 'Chris', 'Chris', 'Darius', 'Darius', 'Darius', 'Darius', 'Dave', 'Dave', 'Elba', 'Emma', 'Emma', 'Erika', 'Erika', 'Erika', 'Hannah', 'Hannah', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Katie', 'Lizzie', 'Lizzie', 'Maria', 'Mike', 'Mike', 'Mike', 'Mike', 'Mike', 'Owen', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Ruth', 'Tasmin', 'Tasmin', 'Tasmin', 'Tasmin']

# %%
print(len(swimmers))
# Out:
# 60

# %%
print(list(set(swimmers)))
# Out:
# ['Emma', 'Darius', 'Lizzie', 'Chris', 'Maria', 'Calvin', 'Ali', 'Hannah', 'Blake', 'Ruth', 'Bill', 'Erika', 'Owen', 'Mike', 'Alison', 'Katie', 'Carl', 'Tasmin', 'Aurora', 'Dave', 'Abi', 'Elba']

# %%
print(len(list(set(swimmers))))
# Out:
# 22
