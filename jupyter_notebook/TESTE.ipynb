# %%
import swimclub

# %%
data = swimclub.read_swim_data("Abi-10-50m-Free.txt")

# %%
data
# Out:
# ('Abi', '10', '50m', 'Free', ['39.07', '37.66', '36.13', '39.42'], '0:39.42')

# %%
times = data[4]

# %%
times
# Out:
# ['39.07', '37.66', '36.13', '39.42']

# %%
nome, idade, distancia, estilo, tempos, tempo_medio = data

# %%
tempos
# Out:
# ['39.07', '37.66', '36.13', '39.42']

# %%
tempo_medio
# Out:
# '0:39.42'
