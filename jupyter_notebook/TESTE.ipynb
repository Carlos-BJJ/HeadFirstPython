# %%
import swimclub
import os
import webbrowser

fn = "Abi-10-50m-Free.txt"

swimclub.read_swim_data(fn)
# Out:
# ('Abi',
#  '10',
#  '50m',
#  'Free',
#  ['39.07', '37.66', '36.13', '39.42'],
#  '0:38.07',
#  [3907, 3766, 3613, 3942])

# %%
nome, idade, distancia, estilo, tempos, media_formatada, convercoes = swimclub.read_swim_data(fn)

# %%
save_to = f"charts/{fn.removesuffix(".txt")}.html"

# %%
with open("test.txt", "a") as fn:
    print(save_to, file = fn)

# %%
swimclub.produce_bar_chart("Lizzie-14-100m-Back.txt")
# Out:
# 'charts/Lizzie-14-100m-Back.html'

# %%
chart = swimclub.produce_bar_chart("Lizzie-14-100m-Back.txt")

webbrowser.open("file://" + os.path.realpath(chart))
# Out:
# True
