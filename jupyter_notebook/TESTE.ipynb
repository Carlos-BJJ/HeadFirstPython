# %%
import swimclub

fn = "Abi-10-50m-Free.txt"

swimclub.read_swim_data(fn)
# Out:
# ('Abi',
#  '10',
#  '50m',
#  'Free',
#  ['39.07', '37.66', '36.13', '39.42'],
#  '0:38.07',
#  [3907, 3766, 3613, 3942])

# %%
*__, tempos, media_formatada, convercoes = swimclub.read_swim_data(fn)

# %%
tempos
# Out:
# ['39.07', '37.66', '36.13', '39.42']

# %%
media_formatada
# Out:
# '0:38.07'

# %%
convercoes
# Out:
# [3907, 3766, 3613, 3942]
